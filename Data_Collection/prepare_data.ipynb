# %%
from imdb import IMDb
import csv
import timeit

ia = IMDb()
movie_names = []
delim = '('
other_delim = ')'
mv = 'movie'
start_yr = 1990
end_yr = 2015
eng = 'English'
braces = '{'
tv = '(TV)'
video = '(V)'
slash = '/'
question = '?'
hyphen = '-'
cast_count = 4

def is_valid(movie):
    if 'year' not in movie.keys() or 'cast' not in movie.keys() or 'genres' not in movie.keys():
        return False
    if 'director' not in movie.keys() or 'title' not in movie.keys() or 'rating' not in movie.keys():
        return False
    year = int(movie['year'])
    if year < start_yr:
        return False
    if year > end_yr:
        return False
    kind = movie['kind']
    if kind!=mv:
        return False
    if 'languages' not in movie.keys():
        return False
    languages = movie['languages'] 
    if eng not in languages:
        return False
    else:
        return True

def get_top_cast(cast):
    top_cast = []
    cast = cast[:cast_count]
    for person in cast:
        top_cast.append(person.personID)
        top_cast.append(person['name'].encode('utf-8'))
    return top_cast
    
def get_top_person(persons):
    top_person = persons[0]
    return [top_person.personID,top_person['name'].encode('utf-8')]

def get_genres(genres):
    return [str(genre) for genre in genres]

def get_persons(persons):
    li = []
    for person in persons:
        li.append(person.personID)
        li.append(person['name'].encode('utf-8'))
    return li

def get_companies(companies):
    li = []
    for company in companies:
        li.append(company.companyID)
        li.append(company['name'].encode('utf-8'))
    return li

def get_list(movie):
    li = []
    li.append(movie.movieID)
    li.append(movie['title'].encode('utf-8'))
    li.append(movie['rating'])
    li.extend(get_top_cast(movie['cast']))
    li.extend(get_top_person(movie['director']))
    # Instead of individual producers we use production companies
    #li.extend(get_persons(movie['producer']))
    if 'production companies' in movie.keys():    
        li.append(len(movie['production companies']))
        li.extend(get_companies(movie['production companies']))
    else:
        li.append(0)
    # Have to check whether we wish to deal with one genre
    if 'genres' in movie.keys():
        li.append(len(movie['genres']))
        li.extend(get_genres(movie['genres']))
    else:
        li.append(0)
    # Have to check whether we wish to deal with one writer
    if 'writers' in movie.keys():
        li.append(len(get_persons(movie['writers'])))
        li.extend(get_persons(movie['writers']))
    else:
        li.append(0)
    if 'votes' in movie.keys():
        li.append(movie['votes'])
    else:
        li.append(0)
    return li
    
data_file = file('ids_set_4', 'r')
data_file_csv = csv.reader(data_file, delimiter=',')
data = []

#keys being written - movieId,title,rating,lead_cast((top 4) name,id),director(top),number of production companies, production companies,
#                     number of genres, genres,number of writers,votes
fp = open('movie_set_4.csv','w')
cnt = 0
#Test purposes
#data_file_csv = data_file_csv[:10]
data = []
i=0
cnt = 0
start_t = timeit.default_timer()
prev_t = start_t
print 'Started Reading'
for row in data_file_csv:
    try:
        movie = ia.get_movie(row[0])
        if i%100 ==0:
            print 'read movie',i,timeit.default_timer() - prev_t
            prev_t = timeit.default_timer()
        if is_valid(movie):
            li = get_list(movie)
            for idx in range(len(li)-1):
                #print idx,li[idx],li[0],li[1]
                fp.write(str(li[idx])+',')
            fp.write(str(li[len(li)-1])+'\n')
            if cnt%50==0:
                print 'append movie',cnt
            cnt +=1
        i+=1
    except:
        pass
stop_t = timeit.default_timer()
fp.close()
print 'Done Reading File','Took ',stop_t-start_t,'secs'
# Out:
# Started Reading
# read movie 0 1.30695192255
# append movie
# 2016-04-04 15:32:17,927 CRITICAL [imdbpy] c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\_exceptions.py:35: IMDbDataAccessError exception raised; args: ({'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0830515/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'},); kwds: {}
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 206, in retrieve_unicode
#     content = uopener.read(**kwds)
#   File "c:\python27\lib\socket.py", line 355, in read
#     data = self._sock.recv(rbufsize)
# timeout: timed out
# CRITICAL:imdbpy:IMDbDataAccessError exception raised; args: ({'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0830515/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'},); kwds: {}
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 206, in retrieve_unicode
#     content = uopener.read(**kwds)
#   File "c:\python27\lib\socket.py", line 355, in read
#     data = self._sock.recv(rbufsize)
# timeout: timed out
# 2016-04-04 15:32:17,927 CRITICAL [imdbpy] c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py:777: caught an exception retrieving or parsing "main" info set for mopID "0830515" (accessSystem: http)
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py", line 772, in update
#     ret = method(mopID)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 506, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'combined')
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 453, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 236, in retrieve_unicode
#     'original exception': e})
# IMDbDataAccessError: {'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0830515/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'}
# CRITICAL:imdbpy:caught an exception retrieving or parsing "main" info set for mopID "0830515" (accessSystem: http)
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py", line 772, in update
#     ret = method(mopID)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 506, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'combined')
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 453, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 236, in retrieve_unicode
#     'original exception': e})
# IMDbDataAccessError: {'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0830515/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'}
#  0
# read movie
# 2016-04-04 15:33:02,571 CRITICAL [imdbpy] c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\_exceptions.py:35: IMDbDataAccessError exception raised; args: ({'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0443649/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'},); kwds: {}
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 206, in retrieve_unicode
#     content = uopener.read(**kwds)
#   File "c:\python27\lib\socket.py", line 355, in read
#     data = self._sock.recv(rbufsize)
# timeout: timed out
# CRITICAL:imdbpy:IMDbDataAccessError exception raised; args: ({'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0443649/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'},); kwds: {}
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 206, in retrieve_unicode
#     content = uopener.read(**kwds)
#   File "c:\python27\lib\socket.py", line 355, in read
#     data = self._sock.recv(rbufsize)
# timeout: timed out
# 2016-04-04 15:33:02,571 CRITICAL [imdbpy] c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py:777: caught an exception retrieving or parsing "main" info set for mopID "0443649" (accessSystem: http)
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py", line 772, in update
#     ret = method(mopID)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 506, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'combined')
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 453, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 236, in retrieve_unicode
#     'original exception': e})
# IMDbDataAccessError: {'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0443649/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'}
# CRITICAL:imdbpy:caught an exception retrieving or parsing "main" info set for mopID "0443649" (accessSystem: http)
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py", line 772, in update
#     ret = method(mopID)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 506, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'combined')
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 453, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 236, in retrieve_unicode
#     'original exception': e})
# IMDbDataAccessError: {'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0443649/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'}
#  100 200.779380624
# append movie 50
# read movie
# 2016-04-04 15:37:07,351 CRITICAL [imdbpy] c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\_exceptions.py:35: IMDbDataAccessError exception raised; args: ({'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0107719/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'},); kwds: {}
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 206, in retrieve_unicode
#     content = uopener.read(**kwds)
#   File "c:\python27\lib\socket.py", line 355, in read
#     data = self._sock.recv(rbufsize)
# timeout: timed out
# CRITICAL:imdbpy:IMDbDataAccessError exception raised; args: ({'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0107719/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'},); kwds: {}
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 206, in retrieve_unicode
#     content = uopener.read(**kwds)
#   File "c:\python27\lib\socket.py", line 355, in read
#     data = self._sock.recv(rbufsize)
# timeout: timed out
# 2016-04-04 15:37:07,351 CRITICAL [imdbpy] c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py:777: caught an exception retrieving or parsing "main" info set for mopID "0107719" (accessSystem: http)
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py", line 772, in update
#     ret = method(mopID)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 506, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'combined')
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 453, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 236, in retrieve_unicode
#     'original exception': e})
# IMDbDataAccessError: {'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0107719/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'}
# CRITICAL:imdbpy:caught an exception retrieving or parsing "main" info set for mopID "0107719" (accessSystem: http)
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py", line 772, in update
#     ret = method(mopID)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 506, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'combined')
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 453, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 236, in retrieve_unicode
#     'original exception': e})
# IMDbDataAccessError: {'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0107719/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'}
# 2016-04-04 15:38:22,447 CRITICAL [imdbpy] c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\_exceptions.py:35: IMDbDataAccessError exception raised; args: ({'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt4510398/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'},); kwds: {}
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 206, in retrieve_unicode
#     content = uopener.read(**kwds)
#   File "c:\python27\lib\socket.py", line 355, in read
#     data = self._sock.recv(rbufsize)
# timeout: timed out
# CRITICAL:imdbpy:IMDbDataAccessError exception raised; args: ({'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt4510398/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'},); kwds: {}
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 206, in retrieve_unicode
#     content = uopener.read(**kwds)
#   File "c:\python27\lib\socket.py", line 355, in read
#     data = self._sock.recv(rbufsize)
# timeout: timed out
# 2016-04-04 15:38:22,447 CRITICAL [imdbpy] c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py:777: caught an exception retrieving or parsing "main" info set for mopID "4510398" (accessSystem: http)
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py", line 772, in update
#     ret = method(mopID)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 506, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'combined')
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 453, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 236, in retrieve_unicode
#     'original exception': e})
# IMDbDataAccessError: {'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt4510398/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'}
# CRITICAL:imdbpy:caught an exception retrieving or parsing "main" info set for mopID "4510398" (accessSystem: http)
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py", line 772, in update
#     ret = method(mopID)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 506, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'combined')
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 453, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 236, in retrieve_unicode
#     'original exception': e})
# IMDbDataAccessError: {'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt4510398/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'}
#  200 192.672797821
# append movie
# 2016-04-04 15:39:31,822 CRITICAL [imdbpy] c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\_exceptions.py:35: IMDbDataAccessError exception raised; args: ({'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0884732/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'},); kwds: {}
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 206, in retrieve_unicode
#     content = uopener.read(**kwds)
#   File "c:\python27\lib\socket.py", line 355, in read
#     data = self._sock.recv(rbufsize)
# timeout: timed out
# CRITICAL:imdbpy:IMDbDataAccessError exception raised; args: ({'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0884732/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'},); kwds: {}
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 206, in retrieve_unicode
#     content = uopener.read(**kwds)
#   File "c:\python27\lib\socket.py", line 355, in read
#     data = self._sock.recv(rbufsize)
# timeout: timed out
# 2016-04-04 15:39:31,822 CRITICAL [imdbpy] c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py:777: caught an exception retrieving or parsing "main" info set for mopID "0884732" (accessSystem: http)
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py", line 772, in update
#     ret = method(mopID)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 506, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'combined')
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 453, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 236, in retrieve_unicode
#     'original exception': e})
# IMDbDataAccessError: {'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0884732/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'}
# CRITICAL:imdbpy:caught an exception retrieving or parsing "main" info set for mopID "0884732" (accessSystem: http)
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py", line 772, in update
#     ret = method(mopID)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 506, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'combined')
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 453, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 236, in retrieve_unicode
#     'original exception': e})
# IMDbDataAccessError: {'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0884732/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'}
#  100
# read movie
# 2016-04-04 15:40:14,059 CRITICAL [imdbpy] c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\_exceptions.py:35: IMDbDataAccessError exception raised; args: ({'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0488380/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'},); kwds: {}
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 206, in retrieve_unicode
#     content = uopener.read(**kwds)
#   File "c:\python27\lib\socket.py", line 355, in read
#     data = self._sock.recv(rbufsize)
# timeout: timed out
# CRITICAL:imdbpy:IMDbDataAccessError exception raised; args: ({'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0488380/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'},); kwds: {}
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 206, in retrieve_unicode
#     content = uopener.read(**kwds)
#   File "c:\python27\lib\socket.py", line 355, in read
#     data = self._sock.recv(rbufsize)
# timeout: timed out
# 2016-04-04 15:40:14,059 CRITICAL [imdbpy] c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py:777: caught an exception retrieving or parsing "main" info set for mopID "0488380" (accessSystem: http)
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py", line 772, in update
#     ret = method(mopID)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 506, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'combined')
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 453, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 236, in retrieve_unicode
#     'original exception': e})
# IMDbDataAccessError: {'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0488380/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'}
# CRITICAL:imdbpy:caught an exception retrieving or parsing "main" info set for mopID "0488380" (accessSystem: http)
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py", line 772, in update
#     ret = method(mopID)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 506, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'combined')
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 453, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 236, in retrieve_unicode
#     'original exception': e})
# IMDbDataAccessError: {'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0488380/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'}
# 2016-04-04 15:41:22,691 CRITICAL [imdbpy] c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\_exceptions.py:35: IMDbDataAccessError exception raised; args: ({'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt1606378/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'},); kwds: {}
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 206, in retrieve_unicode
#     content = uopener.read(**kwds)
#   File "c:\python27\lib\socket.py", line 355, in read
#     data = self._sock.recv(rbufsize)
# timeout: timed out
# CRITICAL:imdbpy:IMDbDataAccessError exception raised; args: ({'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt1606378/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'},); kwds: {}
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 206, in retrieve_unicode
#     content = uopener.read(**kwds)
#   File "c:\python27\lib\socket.py", line 355, in read
#     data = self._sock.recv(rbufsize)
# timeout: timed out
# 2016-04-04 15:41:22,697 CRITICAL [imdbpy] c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py:777: caught an exception retrieving or parsing "main" info set for mopID "1606378" (accessSystem: http)
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py", line 772, in update
#     ret = method(mopID)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 506, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'combined')
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 453, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 236, in retrieve_unicode
#     'original exception': e})
# IMDbDataAccessError: {'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt1606378/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'}
# CRITICAL:imdbpy:caught an exception retrieving or parsing "main" info set for mopID "1606378" (accessSystem: http)
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py", line 772, in update
#     ret = method(mopID)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 506, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'combined')
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 453, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 236, in retrieve_unicode
#     'original exception': e})
# IMDbDataAccessError: {'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt1606378/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'}
# 2016-04-04 15:42:52,559 CRITICAL [imdbpy] c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\_exceptions.py:35: IMDbDataAccessError exception raised; args: ({'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0119567/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'},); kwds: {}
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 206, in retrieve_unicode
#     content = uopener.read(**kwds)
#   File "c:\python27\lib\socket.py", line 355, in read
#     data = self._sock.recv(rbufsize)
# timeout: timed out
# CRITICAL:imdbpy:IMDbDataAccessError exception raised; args: ({'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0119567/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'},); kwds: {}
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 206, in retrieve_unicode
#     content = uopener.read(**kwds)
#   File "c:\python27\lib\socket.py", line 355, in read
#     data = self._sock.recv(rbufsize)
# timeout: timed out
# 2016-04-04 15:42:52,559 CRITICAL [imdbpy] c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py:777: caught an exception retrieving or parsing "main" info set for mopID "0119567" (accessSystem: http)
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py", line 772, in update
#     ret = method(mopID)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 506, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'combined')
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 453, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 236, in retrieve_unicode
#     'original exception': e})
# IMDbDataAccessError: {'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0119567/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'}
# CRITICAL:imdbpy:caught an exception retrieving or parsing "main" info set for mopID "0119567" (accessSystem: http)
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py", line 772, in update
#     ret = method(mopID)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 506, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'combined')
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 453, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 236, in retrieve_unicode
#     'original exception': e})
# IMDbDataAccessError: {'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0119567/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'}
# 2016-04-04 15:43:36,105 CRITICAL [imdbpy] c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\_exceptions.py:35: IMDbDataAccessError exception raised; args: ({'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0078133/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'},); kwds: {}
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 206, in retrieve_unicode
#     content = uopener.read(**kwds)
#   File "c:\python27\lib\socket.py", line 355, in read
#     data = self._sock.recv(rbufsize)
# timeout: timed out
# CRITICAL:imdbpy:IMDbDataAccessError exception raised; args: ({'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0078133/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'},); kwds: {}
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 206, in retrieve_unicode
#     content = uopener.read(**kwds)
#   File "c:\python27\lib\socket.py", line 355, in read
#     data = self._sock.recv(rbufsize)
# timeout: timed out
# 2016-04-04 15:43:36,115 CRITICAL [imdbpy] c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py:777: caught an exception retrieving or parsing "main" info set for mopID "0078133" (accessSystem: http)
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py", line 772, in update
#     ret = method(mopID)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 506, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'combined')
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 453, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 236, in retrieve_unicode
#     'original exception': e})
# IMDbDataAccessError: {'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0078133/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'}
# CRITICAL:imdbpy:caught an exception retrieving or parsing "main" info set for mopID "0078133" (accessSystem: http)
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py", line 772, in update
#     ret = method(mopID)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 506, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'combined')
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 453, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 236, in retrieve_unicode
#     'original exception': e})
# IMDbDataAccessError: {'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0078133/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'}
#  300 230.943116774
# read movie 400 266.004428315
# append movie
# 2016-04-04 15:46:59,293 CRITICAL [imdbpy] c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\_exceptions.py:35: IMDbDataAccessError exception raised; args: ({'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0113987/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'},); kwds: {}
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 206, in retrieve_unicode
#     content = uopener.read(**kwds)
#   File "c:\python27\lib\socket.py", line 355, in read
#     data = self._sock.recv(rbufsize)
# timeout: timed out
# CRITICAL:imdbpy:IMDbDataAccessError exception raised; args: ({'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0113987/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'},); kwds: {}
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 206, in retrieve_unicode
#     content = uopener.read(**kwds)
#   File "c:\python27\lib\socket.py", line 355, in read
#     data = self._sock.recv(rbufsize)
# timeout: timed out
# 2016-04-04 15:46:59,293 CRITICAL [imdbpy] c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py:777: caught an exception retrieving or parsing "main" info set for mopID "0113987" (accessSystem: http)
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py", line 772, in update
#     ret = method(mopID)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 506, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'combined')
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 453, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 236, in retrieve_unicode
#     'original exception': e})
# IMDbDataAccessError: {'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0113987/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'}
# CRITICAL:imdbpy:caught an exception retrieving or parsing "main" info set for mopID "0113987" (accessSystem: http)
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py", line 772, in update
#     ret = method(mopID)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 506, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'combined')
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 453, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 236, in retrieve_unicode
#     'original exception': e})
# IMDbDataAccessError: {'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0113987/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'}
#  150
# read movie 500 180.036504673
# append movie
# 2016-04-04 15:49:36,844 CRITICAL [imdbpy] c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\_exceptions.py:35: IMDbDataAccessError exception raised; args: ({'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0758758/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'},); kwds: {}
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 206, in retrieve_unicode
#     content = uopener.read(**kwds)
#   File "c:\python27\lib\socket.py", line 355, in read
#     data = self._sock.recv(rbufsize)
# timeout: timed out
# CRITICAL:imdbpy:IMDbDataAccessError exception raised; args: ({'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0758758/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'},); kwds: {}
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 206, in retrieve_unicode
#     content = uopener.read(**kwds)
#   File "c:\python27\lib\socket.py", line 355, in read
#     data = self._sock.recv(rbufsize)
# timeout: timed out
# 2016-04-04 15:49:36,851 CRITICAL [imdbpy] c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py:777: caught an exception retrieving or parsing "main" info set for mopID "0758758" (accessSystem: http)
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py", line 772, in update
#     ret = method(mopID)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 506, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'combined')
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 453, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 236, in retrieve_unicode
#     'original exception': e})
# IMDbDataAccessError: {'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0758758/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'}
# CRITICAL:imdbpy:caught an exception retrieving or parsing "main" info set for mopID "0758758" (accessSystem: http)
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py", line 772, in update
#     ret = method(mopID)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 506, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'combined')
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 453, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 236, in retrieve_unicode
#     'original exception': e})
# IMDbDataAccessError: {'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0758758/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'}
#  200
# read movie
# 2016-04-04 15:50:32,657 CRITICAL [imdbpy] c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\_exceptions.py:35: IMDbDataAccessError exception raised; args: ({'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0356634/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'},); kwds: {}
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 206, in retrieve_unicode
#     content = uopener.read(**kwds)
#   File "c:\python27\lib\socket.py", line 355, in read
#     data = self._sock.recv(rbufsize)
# timeout: timed out
# CRITICAL:imdbpy:IMDbDataAccessError exception raised; args: ({'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0356634/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'},); kwds: {}
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 206, in retrieve_unicode
#     content = uopener.read(**kwds)
#   File "c:\python27\lib\socket.py", line 355, in read
#     data = self._sock.recv(rbufsize)
# timeout: timed out
# 2016-04-04 15:50:32,667 CRITICAL [imdbpy] c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py:777: caught an exception retrieving or parsing "main" info set for mopID "0356634" (accessSystem: http)
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py", line 772, in update
#     ret = method(mopID)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 506, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'combined')
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 453, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 236, in retrieve_unicode
#     'original exception': e})
# IMDbDataAccessError: {'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0356634/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'}
# CRITICAL:imdbpy:caught an exception retrieving or parsing "main" info set for mopID "0356634" (accessSystem: http)
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py", line 772, in update
#     ret = method(mopID)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 506, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'combined')
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 453, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 236, in retrieve_unicode
#     'original exception': e})
# IMDbDataAccessError: {'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0356634/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'}
#  600 174.386188528
# append movie 250
# read movie
# 2016-04-04 15:53:55,668 CRITICAL [imdbpy] c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\_exceptions.py:35: IMDbDataAccessError exception raised; args: ({'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0395699/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'},); kwds: {}
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 206, in retrieve_unicode
#     content = uopener.read(**kwds)
#   File "c:\python27\lib\socket.py", line 355, in read
#     data = self._sock.recv(rbufsize)
# timeout: timed out
# CRITICAL:imdbpy:IMDbDataAccessError exception raised; args: ({'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0395699/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'},); kwds: {}
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 206, in retrieve_unicode
#     content = uopener.read(**kwds)
#   File "c:\python27\lib\socket.py", line 355, in read
#     data = self._sock.recv(rbufsize)
# timeout: timed out
# 2016-04-04 15:53:55,668 CRITICAL [imdbpy] c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py:777: caught an exception retrieving or parsing "main" info set for mopID "0395699" (accessSystem: http)
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py", line 772, in update
#     ret = method(mopID)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 506, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'combined')
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 453, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 236, in retrieve_unicode
#     'original exception': e})
# IMDbDataAccessError: {'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0395699/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'}
# CRITICAL:imdbpy:caught an exception retrieving or parsing "main" info set for mopID "0395699" (accessSystem: http)
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py", line 772, in update
#     ret = method(mopID)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 506, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'combined')
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 453, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 236, in retrieve_unicode
#     'original exception': e})
# IMDbDataAccessError: {'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0395699/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'}
# 2016-04-04 15:54:29,884 CRITICAL [imdbpy] c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\_exceptions.py:35: IMDbDataAccessError exception raised; args: ({'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0385752/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'},); kwds: {}
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 206, in retrieve_unicode
#     content = uopener.read(**kwds)
#   File "c:\python27\lib\socket.py", line 355, in read
#     data = self._sock.recv(rbufsize)
# timeout: timed out
# CRITICAL:imdbpy:IMDbDataAccessError exception raised; args: ({'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0385752/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'},); kwds: {}
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 206, in retrieve_unicode
#     content = uopener.read(**kwds)
#   File "c:\python27\lib\socket.py", line 355, in read
#     data = self._sock.recv(rbufsize)
# timeout: timed out
# 2016-04-04 15:54:29,884 CRITICAL [imdbpy] c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py:777: caught an exception retrieving or parsing "main" info set for mopID "0385752" (accessSystem: http)
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py", line 772, in update
#     ret = method(mopID)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 506, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'combined')
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 453, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 236, in retrieve_unicode
#     'original exception': e})
# IMDbDataAccessError: {'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0385752/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'}
# CRITICAL:imdbpy:caught an exception retrieving or parsing "main" info set for mopID "0385752" (accessSystem: http)
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py", line 772, in update
#     ret = method(mopID)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 506, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'combined')
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 453, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 236, in retrieve_unicode
#     'original exception': e})
# IMDbDataAccessError: {'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0385752/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'}
# ...
#   File "c:\python27\lib\socket.py", line 355, in read
#     data = self._sock.recv(rbufsize)
# timeout: timed out
# 2016-04-04 17:59:23,467 CRITICAL [imdbpy] c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py:777: caught an exception retrieving or parsing "main" info set for mopID "1800741" (accessSystem: http)
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py", line 772, in update
#     ret = method(mopID)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 506, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'combined')
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 453, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 236, in retrieve_unicode
#     'original exception': e})
# IMDbDataAccessError: {'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt1800741/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'}
# CRITICAL:imdbpy:caught an exception retrieving or parsing "main" info set for mopID "1800741" (accessSystem: http)
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py", line 772, in update
#     ret = method(mopID)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 506, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'combined')
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 453, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 236, in retrieve_unicode
#     'original exception': e})
# IMDbDataAccessError: {'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt1800741/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'}
# 2016-04-04 17:59:59,513 CRITICAL [imdbpy] c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\_exceptions.py:35: IMDbDataAccessError exception raised; args: ({'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0104691/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'},); kwds: {}
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 206, in retrieve_unicode
#     content = uopener.read(**kwds)
#   File "c:\python27\lib\socket.py", line 355, in read
#     data = self._sock.recv(rbufsize)
# timeout: timed out
# CRITICAL:imdbpy:IMDbDataAccessError exception raised; args: ({'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0104691/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'},); kwds: {}
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 206, in retrieve_unicode
#     content = uopener.read(**kwds)
#   File "c:\python27\lib\socket.py", line 355, in read
#     data = self._sock.recv(rbufsize)
# timeout: timed out
# 2016-04-04 17:59:59,513 CRITICAL [imdbpy] c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py:777: caught an exception retrieving or parsing "main" info set for mopID "0104691" (accessSystem: http)
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py", line 772, in update
#     ret = method(mopID)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 506, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'combined')
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 453, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 236, in retrieve_unicode
#     'original exception': e})
# IMDbDataAccessError: {'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0104691/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'}
# CRITICAL:imdbpy:caught an exception retrieving or parsing "main" info set for mopID "0104691" (accessSystem: http)
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py", line 772, in update
#     ret = method(mopID)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 506, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'combined')
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 453, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 236, in retrieve_unicode
#     'original exception': e})
# IMDbDataAccessError: {'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0104691/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'}
#  1850
# read movie
# 2016-04-04 18:01:01,615 CRITICAL [imdbpy] c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\_exceptions.py:35: IMDbDataAccessError exception raised; args: ({'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0385002/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'},); kwds: {}
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 206, in retrieve_unicode
#     content = uopener.read(**kwds)
#   File "c:\python27\lib\socket.py", line 355, in read
#     data = self._sock.recv(rbufsize)
# timeout: timed out
# CRITICAL:imdbpy:IMDbDataAccessError exception raised; args: ({'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0385002/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'},); kwds: {}
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 206, in retrieve_unicode
#     content = uopener.read(**kwds)
#   File "c:\python27\lib\socket.py", line 355, in read
#     data = self._sock.recv(rbufsize)
# timeout: timed out
# 2016-04-04 18:01:01,615 CRITICAL [imdbpy] c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py:777: caught an exception retrieving or parsing "main" info set for mopID "0385002" (accessSystem: http)
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py", line 772, in update
#     ret = method(mopID)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 506, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'combined')
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 453, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 236, in retrieve_unicode
#     'original exception': e})
# IMDbDataAccessError: {'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0385002/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'}
# CRITICAL:imdbpy:caught an exception retrieving or parsing "main" info set for mopID "0385002" (accessSystem: http)
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py", line 772, in update
#     ret = method(mopID)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 506, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'combined')
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 453, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 236, in retrieve_unicode
#     'original exception': e})
# IMDbDataAccessError: {'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0385002/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'}
# 2016-04-04 18:01:39,171 CRITICAL [imdbpy] c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\_exceptions.py:35: IMDbDataAccessError exception raised; args: ({'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0977855/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'},); kwds: {}
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 206, in retrieve_unicode
#     content = uopener.read(**kwds)
#   File "c:\python27\lib\socket.py", line 355, in read
#     data = self._sock.recv(rbufsize)
# timeout: timed out
# CRITICAL:imdbpy:IMDbDataAccessError exception raised; args: ({'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0977855/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'},); kwds: {}
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 206, in retrieve_unicode
#     content = uopener.read(**kwds)
#   File "c:\python27\lib\socket.py", line 355, in read
#     data = self._sock.recv(rbufsize)
# timeout: timed out
# 2016-04-04 18:01:39,177 CRITICAL [imdbpy] c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py:777: caught an exception retrieving or parsing "main" info set for mopID "0977855" (accessSystem: http)
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py", line 772, in update
#     ret = method(mopID)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 506, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'combined')
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 453, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 236, in retrieve_unicode
#     'original exception': e})
# IMDbDataAccessError: {'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0977855/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'}
# CRITICAL:imdbpy:caught an exception retrieving or parsing "main" info set for mopID "0977855" (accessSystem: http)
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py", line 772, in update
#     ret = method(mopID)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 506, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'combined')
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 453, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 236, in retrieve_unicode
#     'original exception': e})
# IMDbDataAccessError: {'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0977855/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'}
#  4800 201.661575411
# append movie
# 2016-04-04 18:03:36,359 CRITICAL [imdbpy] c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\_exceptions.py:35: IMDbDataAccessError exception raised; args: ({'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0244000/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'},); kwds: {}
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 206, in retrieve_unicode
#     content = uopener.read(**kwds)
#   File "c:\python27\lib\socket.py", line 355, in read
#     data = self._sock.recv(rbufsize)
# timeout: timed out
# CRITICAL:imdbpy:IMDbDataAccessError exception raised; args: ({'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0244000/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'},); kwds: {}
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 206, in retrieve_unicode
#     content = uopener.read(**kwds)
#   File "c:\python27\lib\socket.py", line 355, in read
#     data = self._sock.recv(rbufsize)
# timeout: timed out
# 2016-04-04 18:03:36,359 CRITICAL [imdbpy] c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py:777: caught an exception retrieving or parsing "main" info set for mopID "0244000" (accessSystem: http)
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py", line 772, in update
#     ret = method(mopID)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 506, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'combined')
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 453, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 236, in retrieve_unicode
#     'original exception': e})
# IMDbDataAccessError: {'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0244000/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'}
# CRITICAL:imdbpy:caught an exception retrieving or parsing "main" info set for mopID "0244000" (accessSystem: http)
# Traceback (most recent call last):
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\__init__.py", line 772, in update
#     ret = method(mopID)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 506, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'combined')
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 453, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#   File "c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\parser\http\__init__.py", line 236, in retrieve_unicode
#     'original exception': e})
# IMDbDataAccessError: {'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0244000/combined', 'errcode': None, 'proxy': '', 'original exception': timeout('timed out',), 'errmsg': 'None'}
#  1900
# read movie 4900 236.744577857
# append movie 1950
# Done Reading File Took  9456.61041652 secs

# %%
print len(data)
with open('movie_set_1.csv','wb') as out:
    csv_out=csv.writer(out)
    for row in data:
        csv_out.writerow(str(row))
# Out:
# 11

# %%
#ia = IMDb(accessSystem='http')
movie = ia.get_movie('0022386')
if 'la'
print movie['title'],movie['languages'],movie['director'],movie['kind'],movie['rating'],movie['miscellaneous crew'],movie['genres']
print type(movie['director'][0]),'##',movie['producer'],'##', movie['production companies']

# %%
print movie['director'][0].keys()
# Out:
# ['name', 'canonical name', 'long imdb name', 'long imdb canonical name']

# %%
print movie['director'],movie.movieID,movie['producer']
# Out:
# [<Person id:0783629[http] name:_Selwyn, Edgar_>] 0022386 [<Person id:0856921[http] name:_Thalberg, Irving_>]

# %%
print movie['director'][0].personID,movie['director'][0]['name']
# Out:
#  0783629 Edgar Selwyn

# %%
print movie['year'],movie['production companies'],movie['languages']
# Out:
# 2014 [<Company id:0283021[http] name:_Aunt Max Entertainment_>]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-64-439b18e62560> in <module>()
# ----> 1 print movie['year'],movie['production companies'],movie['languages']
#
# c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\utils.pyc in __getitem__(self, key)
#    1467         # Handle key aliases.
#    1468         key = self.keys_alias.get(key, key)
# -> 1469         rawData = self.data[key]
#    1470         if key in self.keys_tomodify and \
#    1471                 self.modFunct not in (None, modNull):
#
# KeyError: 'languages'

# %%
movie = ia.get_movie('0848228')
print movie['title'],movie['languages'],movie['director'],movie['kind'],movie['rating'],movie['cast'][5],movie['genres']
# Out:
#  The Avengers [u'English', u'Russian'] [<Person id:0923736[http] name:_Whedon, Joss_>] movie 8.1 Jeremy Renner [u'Action', u'Adventure', u'Sci-Fi']

# %%
movie['genre'],movie['production companies']
# Out:
# ([u'Action', u'Adventure', u'Sci-Fi'],
#  [<Company id:0051941[http] name:_Marvel Studios_>,
#   <Company id:0023400[http] name:_Paramount Pictures_>])

# %%
movie['sound crew'][0],movie['production companies'][0].companyID
# Out:
# (<Person id:1918170[http] name:_Bautista, Eric_>, '0051941')

# %%
movie['editor'],'##',movie['writer'][0],'##',movie['producer']
# Out:
# ([<Person id:0285701[http] name:_Ford, Jeffrey_>,
#   <Person id:0489809[http] name:_Lassek, Lisa_>],
#  '##',
#  <Person id:0923736[http] name:_Whedon, Joss_>,
#  '##',
#  [<Person id:0022285[http] name:_Alonso, Victoria_>,
#   <Person id:0195669[http] name:_D'Esposito, Louis_>,
#   <Person id:0269463[http] name:_Favreau, Jon_>,
#   <Person id:0270559[http] name:_Feige, Kevin_>,
#   <Person id:2643957[http] name:_Fine, Alan_>,
#   <Person id:1436246[http] name:_Latcham, Jeremy_>,
#   <Person id:0498278[http] name:_Lee, Stan_>,
#   <Person id:0924357[http] name:_Whitcher, Patricia_>])

# %%
movie['votes']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-dd7835a3a42a> in <module>()
# ----> 1 movie['votes']
#
# c:\python27\lib\site-packages\imdbpy-5.0-py2.7-win-amd64.egg\imdb\utils.pyc in __getitem__(self, key)
#    1467         # Handle key aliases.
#    1468         key = self.keys_alias.get(key, key)
# -> 1469         rawData = self.data[key]
#    1470         if key in self.keys_tomodify and \
#    1471                 self.modFunct not in (None, modNull):
#
# KeyError: 'votes'

# %%
l = [u'English', u'French']
if 'English' in l:
    print 'YES'
# Out:
#  YES

# %%
t=[]
t.append(1)
t.append(2)
t
# Out:
# [1, 2]

# %%
t.append([3,4])

# %%
t
# Out:
# [1, 2, [3, 4]]

# %%
t=[1,2]
t
# Out:
# [1, 2]

# %%
[(s+2,s+3) for s in t]
# Out:
# [(3, 4), (4, 5)]
